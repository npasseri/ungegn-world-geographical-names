# %% [markdown]
# # **Código principal**

# %%
# -- Importação de pacotes e bibliotecas
import pandas as pd
import json
from urllib.request import urlopen
from io import StringIO

# %%
# -- Leitura do csv como dataframe
capitais_df = pd.read_csv('capitais.csv')

# %%
# -- Exibição das linhas iniciais
capitais_df.head()
# Out:
#                country              city  \
# 0              Albania            Tirana
# 1              Algeria           Algiers
# 2              Andorra  Andorra la Vella
# 3  Antigua and Barbuda      Saint John's
# 4              Armenia           Yerevan
#
#                                                  URL
# 0                             https://www.tirana.al/
# 1                    https://www.apc-algercentre.dz/
# 2  https://www.andorra.ad/en/parroquia/andorra-la...
# 3                 https://www.cityofjohnstownpa.net/
# 4                            https://www.yerevan.am/

# %%
# -- Resumo do dataframe
capitais_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  132 non-null    object
#  1   city     132 non-null    object
#  2   URL      132 non-null    object
# dtypes: object(3)
# memory usage: 3.2+ KB

# %%
# -- Duplicação da coluna URL
capitais_df['domain'] = capitais_df['URL']

# %%
# -- Extração do domínio
capitais_df['domain'] = capitais_df['domain'].map(lambda url: url.replace('https://www.', ''))
capitais_df['domain'] = capitais_df['domain'].map(lambda url: url.replace('https://', ''))
capitais_df['domain'] = capitais_df['domain'].map(lambda url: url.replace('http://www.', ''))
capitais_df['domain'] = capitais_df['domain'].map(lambda url: url.replace('http://', ''))
capitais_df['domain'] = capitais_df['domain'].map(lambda url: url.replace(url[len(url)-1], '') if url.endswith('/') else url) # remoção da '/' ao final do domínio

# %%
# -- Exibição das linhas iniciais
capitais_df.head()
# Out:
#                country              city  \
# 0              Albania            Tirana
# 1              Algeria           Algiers
# 2              Andorra  Andorra la Vella
# 3  Antigua and Barbuda      Saint John's
# 4              Armenia           Yerevan
#
#                                                  URL  \
# 0                             https://www.tirana.al/
# 1                    https://www.apc-algercentre.dz/
# 2  https://www.andorra.ad/en/parroquia/andorra-la...
# 3                 https://www.cityofjohnstownpa.net/
# 4                            https://www.yerevan.am/
#
#                                      domain
# 0                                 tirana.al
# 1                        apc-algercentre.dz
# 2  andorra.ad/en/parroquia/andorra-la-vella
# 3                     cityofjohnstownpa.net
# 4                                yerevan.am

# %%
# -- Exibição das linhas finais
capitais_df.tail()
# Out:
#             country              city  \
# 127         Vanuatu         Port-Vila
# 128  Virgin Islands  Charlotte Amalie
# 129  Western Sahara          El Aaiún
# 130           Yemen             Sanaa
# 131          Zambia            Lusaka
#
#                                                 URL  \
# 127            https://www.portvilamunicipality.vu/
# 128  https://www.vi.gov/st-thomas-st-john-district/
# 129                                       Not Known
# 130                                       Not known
# 131                         https://www.lcc.gov.zm/
#
#                                domain
# 127           portvilamunicipality.vu
# 128  vi.govst-thomas-st-john-district
# 129                         Not Known
# 130                         Not known
# 131                        lcc.gov.zm

# %%
# -- Definição da coluna pdf_filter_URL para criação dos links de requisição com os filtros necessários

IA_URL_prefix = 'https://web.archive.org/cdx/search/cdx?url='
IA_URL_suffix = '&matchType=domain&filter=mimetype:application/pdf&fl=timestamp,urlkey,original&output=json'

capitais_df['pdf_filter_URL'] = capitais_df.loc[(capitais_df['domain'] != 'Not known') & (capitais_df['domain'] != 'Not Known')].apply(lambda row: IA_URL_prefix + row['domain'] + IA_URL_suffix, axis=1)

# %%
# -- Exibição das linhas iniciais
capitais_df.head()
# Out:
#                country              city  \
# 0              Albania            Tirana
# 1              Algeria           Algiers
# 2              Andorra  Andorra la Vella
# 3  Antigua and Barbuda      Saint John's
# 4              Armenia           Yerevan
#
#                                                  URL  \
# 0                             https://www.tirana.al/
# 1                    https://www.apc-algercentre.dz/
# 2  https://www.andorra.ad/en/parroquia/andorra-la...
# 3                 https://www.cityofjohnstownpa.net/
# 4                            https://www.yerevan.am/
#
#                                      domain  \
# 0                                 tirana.al
# 1                        apc-algercentre.dz
# 2  andorra.ad/en/parroquia/andorra-la-vella
# 3                     cityofjohnstownpa.net
# 4                                yerevan.am
#
#                                       pdf_filter_URL
# 0  https://web.archive.org/cdx/search/cdx?url=tir...
# 1  https://web.archive.org/cdx/search/cdx?url=apc...
# 2  https://web.archive.org/cdx/search/cdx?url=and...
# 3  https://web.archive.org/cdx/search/cdx?url=cit...
# 4  https://web.archive.org/cdx/search/cdx?url=yer...

# %%
# -- Exibição das linhas finais
capitais_df.tail()
# Out:
#             country              city  \
# 127         Vanuatu         Port-Vila
# 128  Virgin Islands  Charlotte Amalie
# 129  Western Sahara          El Aaiún
# 130           Yemen             Sanaa
# 131          Zambia            Lusaka
#
#                                                 URL  \
# 127            https://www.portvilamunicipality.vu/
# 128  https://www.vi.gov/st-thomas-st-john-district/
# 129                                       Not Known
# 130                                       Not known
# 131                         https://www.lcc.gov.zm/
#
#                                domain  \
# 127           portvilamunicipality.vu
# 128  vi.govst-thomas-st-john-district
# 129                         Not Known
# 130                         Not known
# 131                        lcc.gov.zm
#
#                                         pdf_filter_URL
# 127  https://web.archive.org/cdx/search/cdx?url=por...
# 128  https://web.archive.org/cdx/search/cdx?url=vi....
# 129                                                NaN
# 130                                                NaN
# 131  https://web.archive.org/cdx/search/cdx?url=lcc...

# %%
# -- Conversão do dataframe para CSV
capitais_df.to_csv('capitais_pdf_filter_URL.csv', index=False)

# %%
# -- Código para buscar os arquivos PDF disponibilizados para
# -- cada cidade com um link válido

# -- Definição de variáveis auxiliares
final_dataframe = []
response = None
data_json = None
jsonString = None
temp_df = None
header = None
original_pdf_URL = None
split_urlkey = None
capitais_URL = None
IA_pdf_URL = None
IA_prefix = 'https://web.archive.org/web/'

# -- Laço para percorrer o DataFrame capitais_df
for index, row in capitais_df.iterrows():
  if pd.notna(row['pdf_filter_URL']): # Condição de exclusão para cidades para as quais não conhecemos o link

    response = urlopen(row['pdf_filter_URL']) # Abrir o link com a requisição buscando arquivos PDF
    data_json = json.loads(response.read()) # Carregar a resposta
    jsonString = json.dumps(data_json) # Converter para JSON

    # -- Conversão do JSON para um Dataframe temporário
    # -- Este DataFrame será composto pelas colunas "timestamp", "urlkey" e "original"
    # -- que foram selecionadas no link de requisição
    temp_df = pd.read_json(StringIO(jsonString)) 

    # -- Readequação do cabeçalho: atribuição de "timestamp", "urlkey" e "original" como títulos das colunas
    try:
      header = temp_df.iloc[0]
      temp_df = temp_df[1:]
      temp_df.columns = header

      # -- Laço para percorrer temp_df de modo a coletar a URL original
      # -- e criar a URL de armazenamento no Internet Archive
      for index_temp_df, row_temp_df in temp_df.iterrows():
        original_pdf_URL = row_temp_df['original'] # Armazenamento da URL original do PDF
      
        split_urlkey = row_temp_df['urlkey'].split('/', 1) # Divisão de urlkey na primeira barra
        timestamp_url = row_temp_df['timestamp'] + 'if_/' # Coleta do timestamp e inclusão da cláusula if_ (para acesso direto ao arquivo PDF)
        capitais_URL = row['URL'] # URL do site presente em capitais_df
        IA_pdf_URL = IA_prefix + timestamp_url + capitais_URL + split_urlkey[1] # Criação do link do PDF no IA

        # -- Inserção dos dados em final_dataframe na forma de dicionário
        final_dataframe.append(
          {
            'country': row['country'],
            'city': row['city'],
            'original_pdf_URL': original_pdf_URL,
            'IA_pdf_URL': IA_pdf_URL
          }
        )

      # -- Redefinição das variáveis auxiliares
      response = None
      data_json = None
      jsonString = None
      temp_df = None
      header = None
      original_pdf_URL = None
      split_urlkey = None
      capitais_URL = None
      IA_pdf_URL = None

    # -- Tratamento de erros com a identificação de Index, Country e a exceção levantada
    except Exception as exc:
      print(f"Index: {index} ### Country: {row['country']} ### Error: {exc}")

# -- Criação de DataFrame a partir da lista de dicionários
capitais_final_df = pd.DataFrame(final_dataframe)
# Out:
# Index: 5 ### Country: Aruba ### Error: single positional indexer is out-of-bounds
# Index: 6 ### Country: Azerbaijan ### Error: single positional indexer is out-of-bounds
# Index: 7 ### Country: Bahamas ### Error: single positional indexer is out-of-bounds
# Index: 8 ### Country: Bahrain ### Error: single positional indexer is out-of-bounds
# Index: 11 ### Country: Benin ### Error: single positional indexer is out-of-bounds
# Index: 15 ### Country: Botswana ### Error: single positional indexer is out-of-bounds
# Index: 16 ### Country: Brunei ### Error: single positional indexer is out-of-bounds
# Index: 21 ### Country: Cape Verde ### Error: single positional indexer is out-of-bounds
# Index: 22 ### Country: Cayman Islands ### Error: single positional indexer is out-of-bounds
# Index: 24 ### Country: Chad ### Error: single positional indexer is out-of-bounds
# Index: 25 ### Country: Comoros ### Error: single positional indexer is out-of-bounds
# Index: 26 ### Country: Cuba ### Error: single positional indexer is out-of-bounds
# Index: 27 ### Country: Curacao ### Error: single positional indexer is out-of-bounds
# Index: 29 ### Country: Djibouti ### Error: single positional indexer is out-of-bounds
# Index: 30 ### Country: Dominica ### Error: single positional indexer is out-of-bounds
# Index: 32 ### Country: East Timor ### Error: single positional indexer is out-of-bounds
# Index: 34 ### Country: Equatorial Guinea ### Error: single positional indexer is out-of-bounds
# Index: 35 ### Country: Eritrea ### Error: single positional indexer is out-of-bounds
# Index: 36 ### Country: Estonia ### Error: single positional indexer is out-of-bounds
# Index: 45 ### Country: Grenada ### Error: single positional indexer is out-of-bounds
# Index: 47 ### Country: Guernsey ### Error: single positional indexer is out-of-bounds
# Index: 50 ### Country: Guyana ### Error: single positional indexer is out-of-bounds
# Index: 51 ### Country: Haiti ### Error: single positional indexer is out-of-bounds
# Index: 52 ### Country: Honduras ### Error: single positional indexer is out-of-bounds
# Index: 57 ### Country: Israel ### Error: single positional indexer is out-of-bounds
# Index: 58 ### Country: Ivory Coast ### Error: single positional indexer is out-of-bounds
# Index: 59 ### Country: Jamaica ### Error: single positional indexer is out-of-bounds
# Index: 63 ### Country: Kiribati ### Error: single positional indexer is out-of-bounds
# Index: 64 ### Country: Kosovo ### Error: single positional indexer is out-of-bounds
# Index: 67 ### Country: Laos ### Error: single positional indexer is out-of-bounds
# Index: 69 ### Country: Lebanon ### Error: single positional indexer is out-of-bounds
# Index: 70 ### Country: Lesotho ### Error: single positional indexer is out-of-bounds
# Index: 71 ### Country: Liberia ### Error: single positional indexer is out-of-bounds
# Index: 73 ### Country: Madagascar ### Error: single positional indexer is out-of-bounds
# Index: 74 ### Country: Malawi ### Error: single positional indexer is out-of-bounds
# Index: 76 ### Country: Mali ### Error: single positional indexer is out-of-bounds
# Index: 79 ### Country: Mauritania ### Error: single positional indexer is out-of-bounds
# Index: 80 ### Country: Mauritius ### Error: single positional indexer is out-of-bounds
# Index: 81 ### Country: Mayotte ### Error: single positional indexer is out-of-bounds
# Index: 84 ### Country: Montenegro ### Error: single positional indexer is out-of-bounds
# Index: 85 ### Country: Morocco ### Error: single positional indexer is out-of-bounds
# Index: 86 ### Country: Mozambique ### Error: single positional indexer is out-of-bounds
# Index: 87 ### Country: Myanmar ### Error: single positional indexer is out-of-bounds
# Index: 93 ### Country: Norway ### Error: single positional indexer is out-of-bounds
# Index: 95 ### Country: Pakistan ### Error: single positional indexer is out-of-bounds
# Index: 100 ### Country: Principality of Monaco ### Error: single positional indexer is out-of-bounds
# Index: 101 ### Country: Puerto Rico ### Error: single positional indexer is out-of-bounds
# Index: 102 ### Country: Qatar ### Error: single positional indexer is out-of-bounds
# Index: 104 ### Country: Saint Lucia ### Error: single positional indexer is out-of-bounds
# Index: 105 ### Country: Saint Vincent and the Grenadines ### Error: single positional indexer is out-of-bounds
# Index: 106 ### Country: Samoa ### Error: single positional indexer is out-of-bounds
# Index: 107 ### Country: Sao Tome and Principe ### Error: single positional indexer is out-of-bounds
# Index: 108 ### Country: Serbia ### Error: single positional indexer is out-of-bounds
# Index: 109 ### Country: Seychelles ### Error: single positional indexer is out-of-bounds
# Index: 111 ### Country: Solomon Islands ### Error: single positional indexer is out-of-bounds
# Index: 113 ### Country: Sri Lanka ### Error: single positional indexer is out-of-bounds
# Index: 114 ### Country: Suriname ### Error: single positional indexer is out-of-bounds
# Index: 116 ### Country: Syria ### Error: single positional indexer is out-of-bounds
# Index: 119 ### Country: Tonga ### Error: single positional indexer is out-of-bounds
# Index: 120 ### Country: Trinidad and Tobago ### Error: single positional indexer is out-of-bounds
# Index: 127 ### Country: Vanuatu ### Error: single positional indexer is out-of-bounds
# Index: 128 ### Country: Virgin Islands ### Error: single positional indexer is out-of-bounds

# %%
# -- Exibição das linhas iniciais
capitais_final_df.head()
# Out:
#    country    city                                   original_pdf_URL  \
# 0  Albania  Tirana  https://www.tirana.al/en/uploads/2020/12/20201...
# 1  Albania  Tirana  https://www.tirana.al/en/uploads/2020/12/20201...
# 2  Albania  Tirana  https://tirana.al/en/uploads/2020/12/202012101...
# 3  Albania  Tirana  https://www.tirana.al/en/uploads/2020/12/20201...
# 4  Albania  Tirana  https://www.tirana.al/en/uploads/2020/12/20201...
#
#                                           IA_pdf_URL
# 0  https://web.archive.org/web/20210423052515if_/...
# 1  https://web.archive.org/web/20210503020353if_/...
# 2  https://web.archive.org/web/20220302193349if_/...
# 3  https://web.archive.org/web/20210423054047if_/...
# 4  https://web.archive.org/web/20210503020444if_/...

# %%
# -- Resumo do dataframe
capitais_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329917 entries, 0 to 329916
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   country           329917 non-null  object
#  1   city              329917 non-null  object
#  2   original_pdf_URL  329917 non-null  object
#  3   IA_pdf_URL        329917 non-null  object
# dtypes: object(4)
# memory usage: 10.1+ MB

# %%
# -- Quantidade de cidades distintas
capitais_final_df['city'].nunique()
# Out:
# 64

# %%
# -- Conversão do dataframe para CSV
capitais_final_df.to_csv('capitais_final.csv', index=False)

# %% [markdown]
# # **Testes**

# %%
capitais_final_df['IA_pdf_URL'][1]
# Out:
# 'https://web.archive.org/web/20210503020353if_/https://www.tirana.al/en/uploads/2020/12/20201210161510_sump_tirana-volume-i_status_analysis_200724.pdf'

# %%
from urllib.request import urlopen
import json

# %%
URL_example = 'https://web.archive.org/cdx/search/cdx?url=saipanmayor.net&matchType=domain&filter=mimetype:application/pdf&fl=timestamp,urlkey,original&output=json'

# %%
response = urlopen(URL_example)

# %%
data_json = json.loads(response.read())

# %%
print(data_json)
# Out:
# [['timestamp', 'urlkey', 'original'], ['20200927153039', 'net,saipanmayor)/resources/files/2019%20concession%20application-pg1docx%20new.pdf', 'https://saipanmayor.net/resources/files/2019%20CONCESSION%20APPLICATION-PG1docx%20NEW.pdf'], ['20200927164629', 'net,saipanmayor)/resources/files/2019%20parade%20and%20float%20application%20packet%20(1).pdf', 'https://saipanmayor.net/resources/files/2019%20Parade%20and%20Float%20Application%20Packet%20(1).pdf'], ['20200927170811', 'net,saipanmayor)/resources/files/application%20for%20employment%20final.pdf', 'https://saipanmayor.net/resources/files/Application%20for%20Employment%20Final.pdf'], ['20220625233129', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2019%20citizen%20centric%20report.pdf', 'https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2019%20Citizen%20Centric%20Report.pdf'], ['20220630131922', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2019%20citizen%20centric%20report.pdf', 'https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2019%20Citizen%20Centric%20Report.pdf'], ['20220625222543', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2020%20ccr%20final%20compressed.pdf', 'https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2020%20CCR%20Final%20Compressed.pdf'], ['20220630125940', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2020%20ccr%20final%20compressed.pdf', 'https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2020%20CCR%20Final%20Compressed.pdf'], ['20220625220850', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2021%20citizen%20centric%20report%20compressed.pdf', 'https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2021%20Citizen%20Centric%20Report%20Compressed.pdf'], ['20220630133435', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2021%20citizen%20centric%20report%20compressed.pdf', 'https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2021%20Citizen%20Centric%20Report%20Compressed.pdf'], ['20221203094408', 'net,saipanmayor)/resources/files/citizen%20centric%20reports/2022%20citizen%20centric%20report.pdf', 'https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2022%20Citizen%20Centric%20Report.pdf'], ['20200927162616', 'net,saipanmayor)/resources/files/host%20family%20application%20form%20new.pdf', 'https://saipanmayor.net/resources/files/Host%20Family%20Application%20Form%20NEW.pdf'], ['20200927155046', 'net,saipanmayor)/resources/files/id%20application%202018%20-%20copy-converted.pdf', 'https://saipanmayor.net/resources/files/ID%20APPLICATION%202018%20-%20Copy-converted.pdf'], ['20200927162411', 'net,saipanmayor)/resources/files/id%20application%202018%20-%20fillableform.pdf', 'https://saipanmayor.net/resources/files/ID%20APPLICATION%202018%20-%20FillableForm.pdf'], ['20220630141428', 'net,saipanmayor)/resources/files/liberation%20day/2022/2022%20ldc%20concession%20agreement.pdf', 'https://saipanmayor.net/resources/files/Liberation%20Day/2022/2022%20LDC%20CONCESSION%20AGREEMENT.pdf'], ['20220630125546', 'net,saipanmayor)/resources/files/liberation%20day/2022/2022%20liberation%20parade%20application%20packet.pdf', 'https://saipanmayor.net/resources/files/Liberation%20Day/2022/2022%20Liberation%20Parade%20Application%20Packet.pdf'], ['20200927153754', 'net,saipanmayor)/resources/files/marriage%20application%202019(5).pdf', 'https://saipanmayor.net/resources/files/Marriage%20Application%202019(5).pdf'], ['20220630143237', 'net,saipanmayor)/resources/files/marriage%20application.pdf', 'https://saipanmayor.net/resources/files/Marriage%20Application.pdf'], ['20201127105622', 'net,saipanmayor)/resources/files/mos%20customer%20service%20form%20(1).pdf', 'https://saipanmayor.net/resources/files/MOS%20CUSTOMER%20SERVICE%20FORM%20(1).pdf'], ['20200927165405', 'net,saipanmayor)/resources/files/mos%20customer%20service%20form%20final.pdf', 'https://saipanmayor.ne ...

# %%
jsonString = json.dumps(data_json)

# %%
type(jsonString)
# Out:
# str

# %%
print(jsonString)
# Out:
# [["timestamp", "urlkey", "original"], ["20200927153039", "net,saipanmayor)/resources/files/2019%20concession%20application-pg1docx%20new.pdf", "https://saipanmayor.net/resources/files/2019%20CONCESSION%20APPLICATION-PG1docx%20NEW.pdf"], ["20200927164629", "net,saipanmayor)/resources/files/2019%20parade%20and%20float%20application%20packet%20(1).pdf", "https://saipanmayor.net/resources/files/2019%20Parade%20and%20Float%20Application%20Packet%20(1).pdf"], ["20200927170811", "net,saipanmayor)/resources/files/application%20for%20employment%20final.pdf", "https://saipanmayor.net/resources/files/Application%20for%20Employment%20Final.pdf"], ["20220625233129", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2019%20citizen%20centric%20report.pdf", "https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2019%20Citizen%20Centric%20Report.pdf"], ["20220630131922", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2019%20citizen%20centric%20report.pdf", "https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2019%20Citizen%20Centric%20Report.pdf"], ["20220625222543", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2020%20ccr%20final%20compressed.pdf", "https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2020%20CCR%20Final%20Compressed.pdf"], ["20220630125940", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2020%20ccr%20final%20compressed.pdf", "https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2020%20CCR%20Final%20Compressed.pdf"], ["20220625220850", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2021%20citizen%20centric%20report%20compressed.pdf", "https://www.saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2021%20Citizen%20Centric%20Report%20Compressed.pdf"], ["20220630133435", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2021%20citizen%20centric%20report%20compressed.pdf", "https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2021%20Citizen%20Centric%20Report%20Compressed.pdf"], ["20221203094408", "net,saipanmayor)/resources/files/citizen%20centric%20reports/2022%20citizen%20centric%20report.pdf", "https://saipanmayor.net/resources/files/Citizen%20Centric%20Reports/2022%20Citizen%20Centric%20Report.pdf"], ["20200927162616", "net,saipanmayor)/resources/files/host%20family%20application%20form%20new.pdf", "https://saipanmayor.net/resources/files/Host%20Family%20Application%20Form%20NEW.pdf"], ["20200927155046", "net,saipanmayor)/resources/files/id%20application%202018%20-%20copy-converted.pdf", "https://saipanmayor.net/resources/files/ID%20APPLICATION%202018%20-%20Copy-converted.pdf"], ["20200927162411", "net,saipanmayor)/resources/files/id%20application%202018%20-%20fillableform.pdf", "https://saipanmayor.net/resources/files/ID%20APPLICATION%202018%20-%20FillableForm.pdf"], ["20220630141428", "net,saipanmayor)/resources/files/liberation%20day/2022/2022%20ldc%20concession%20agreement.pdf", "https://saipanmayor.net/resources/files/Liberation%20Day/2022/2022%20LDC%20CONCESSION%20AGREEMENT.pdf"], ["20220630125546", "net,saipanmayor)/resources/files/liberation%20day/2022/2022%20liberation%20parade%20application%20packet.pdf", "https://saipanmayor.net/resources/files/Liberation%20Day/2022/2022%20Liberation%20Parade%20Application%20Packet.pdf"], ["20200927153754", "net,saipanmayor)/resources/files/marriage%20application%202019(5).pdf", "https://saipanmayor.net/resources/files/Marriage%20Application%202019(5).pdf"], ["20220630143237", "net,saipanmayor)/resources/files/marriage%20application.pdf", "https://saipanmayor.net/resources/files/Marriage%20Application.pdf"], ["20201127105622", "net,saipanmayor)/resources/files/mos%20customer%20service%20form%20(1).pdf", "https://saipanmayor.net/resources/files/MOS%20CUSTOMER%20SERVICE%20FORM%20(1).pdf"], ["20200927165405", "net,saipanmayor)/resources/files/mos%20customer%20service%20form%20final.pdf", "https://saipanmayor.ne ...

# %%
df_example = pd.read_json(StringIO(jsonString))

# %%
df_example.head()
# Out:
#                 0                                                  1  \
# 0       timestamp                                             urlkey
# 1  20200927153039  net,saipanmayor)/resources/files/2019%20conces...
# 2  20200927164629  net,saipanmayor)/resources/files/2019%20parade...
# 3  20200927170811  net,saipanmayor)/resources/files/application%2...
# 4  20220625233129  net,saipanmayor)/resources/files/citizen%20cen...
#
#                                                    2
# 0                                           original
# 1  https://saipanmayor.net/resources/files/2019%2...
# 2  https://saipanmayor.net/resources/files/2019%2...
# 3  https://saipanmayor.net/resources/files/Applic...
# 4  https://www.saipanmayor.net/resources/files/Ci...

# %%
header = df_example.iloc[0]
df_example = df_example[1:]
df_example.columns = header

# %%
df_example.head()
# Out:
# 0       timestamp                                             urlkey  \
# 1  20200927153039  net,saipanmayor)/resources/files/2019%20conces...
# 2  20200927164629  net,saipanmayor)/resources/files/2019%20parade...
# 3  20200927170811  net,saipanmayor)/resources/files/application%2...
# 4  20220625233129  net,saipanmayor)/resources/files/citizen%20cen...
# 5  20220630131922  net,saipanmayor)/resources/files/citizen%20cen...
#
# 0                                           original
# 1  https://saipanmayor.net/resources/files/2019%2...
# 2  https://saipanmayor.net/resources/files/2019%2...
# 3  https://saipanmayor.net/resources/files/Applic...
# 4  https://www.saipanmayor.net/resources/files/Ci...
# 5  https://saipanmayor.net/resources/files/Citize...

# %%
df_example['IA_urlkey_pdf'] = df_example['urlkey']

# %%
df_example.head()
# Out:
# 0       timestamp                                             urlkey  \
# 1  20200927153039  net,saipanmayor)/resources/files/2019%20conces...
# 2  20200927164629  net,saipanmayor)/resources/files/2019%20parade...
# 3  20200927170811  net,saipanmayor)/resources/files/application%2...
# 4  20220625233129  net,saipanmayor)/resources/files/citizen%20cen...
# 5  20220630131922  net,saipanmayor)/resources/files/citizen%20cen...
#
# 0                                           original  \
# 1  https://saipanmayor.net/resources/files/2019%2...
# 2  https://saipanmayor.net/resources/files/2019%2...
# 3  https://saipanmayor.net/resources/files/Applic...
# 4  https://www.saipanmayor.net/resources/files/Ci...
# 5  https://saipanmayor.net/resources/files/Citize...
#
# 0                                      IA_urlkey_pdf
# 1  net,saipanmayor)/resources/files/2019%20conces...
# 2  net,saipanmayor)/resources/files/2019%20parade...
# 3  net,saipanmayor)/resources/files/application%2...
# 4  net,saipanmayor)/resources/files/citizen%20cen...
# 5  net,saipanmayor)/resources/files/citizen%20cen...

# %%
df_example.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 1 to 28
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      28 non-null     object
#  1   urlkey         28 non-null     object
#  2   original       28 non-null     object
#  3   IA_urlkey_pdf  28 non-null     object
# dtypes: object(4)
# memory usage: 1.0+ KB

# %%
s = "net,saipanmayor)/resources/files/2019%20parade%20and%20float%20application%20packet%20(1).pdf"
new_prefix = "https://web.archive.org/web/"
split_s = s.split('/', 1)
print(split_s)
new_s = new_prefix + '20220625233129' + 'if_/https://www.saipanmayor.net/' + split_s[1]
print(new_s)
# Out:
# ['net,saipanmayor)', 'resources/files/2019%20parade%20and%20float%20application%20packet%20(1).pdf']
# https://web.archive.org/web/20220625233129if_/https://www.saipanmayor.net/resources/files/2019%20parade%20and%20float%20application%20packet%20(1).pdf

# %%
# -- Modelo 1
f'https://web.archive.org/cdx/search/cdx?url={clean_url}&matchType=domain&filter=mimetype:application/pdf&fl=timestamp,urlkey&output=json'

# %%
# -- Modelo 2
f'https://web.archive.org/web/{timestamp}if_/{coluna_URL}/areas/ciudad/historico/especiales/9julio/acta_independencia.pdf'

# %%
import requests
from requests.exceptions import HTTPError

# %%
content = None
URL = 'https://web.archive.org/cdx/search/cdx?url=buenosaires.gob.ar&matchType=domain&filter=mimetype:application/pdf&fl=timestamp,urlkey&output=json'

try:
  response = requests.get(URL)
  response.raise_for_status()
except HTTPError as exc:
  print(exc)
else:
  content = response.text

print(type(content))
# Out:
# <class 'str'>

# %%
buenos_aires_df = pd.read_json('/content/cdx_buenos_aires.json')

# %%
buenos_aires_df.head()
# Out:
#                 0                                                  1
# 0       timestamp                                             urlkey
# 1  20130810075538  ar,gob,buenosaires)/aplicaciones/guiaba2/virtu...
# 2  20221221063018  ar,gob,buenosaires)/apps/contenido/archivos/10...
# 3  20210309144807  ar,gob,buenosaires)/apps/contenido/archivos/10...
# 4  20220119110328  ar,gob,buenosaires)/apps/contenido/archivos/11...

# %%
buenos_aires_df.tail()
# Out:
#                     0                                                  1
# 28159  20220809174200  ar,gob,buenosaires,vivienda)/guiainquilinospro...
# 28160  20221201204246  ar,gob,buenosaires,vivienda)/organigrama-novie...
# 28161  20220930065626  ar,gob,buenosaires,vivienda)/organigrama-septi...
# 28162  20220809160405  ar,gob,buenosaires,vivienda)/participacionmesa...
# 28163  20220809155251  ar,gob,buenosaires,vivienda)/participacionplan...

# %%
header = buenos_aires_df.iloc[0]
buenos_aires_df = buenos_aires_df[1:]
buenos_aires_df.columns = header

# %%
buenos_aires_df.head()
# Out:
# 0       timestamp                                             urlkey
# 1  20130810075538  ar,gob,buenosaires)/aplicaciones/guiaba2/virtu...
# 2  20221221063018  ar,gob,buenosaires)/apps/contenido/archivos/10...
# 3  20210309144807  ar,gob,buenosaires)/apps/contenido/archivos/10...
# 4  20220119110328  ar,gob,buenosaires)/apps/contenido/archivos/11...
# 5  20220119114714  ar,gob,buenosaires)/apps/contenido/archivos/11...
